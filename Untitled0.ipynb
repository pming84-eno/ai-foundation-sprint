# %% [markdown]
# <a href="https://colab.research.google.com/github/pming84-eno/ai-foundation-sprint/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q transformers datasets sentence-transformers scikit-learn pandas matplotlib seaborn faiss-cpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 93.2 MB/s eta 0:00:00
